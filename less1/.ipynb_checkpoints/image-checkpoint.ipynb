// %%
#include "image.cpp"
#define endl "\n"
extern const im::image hat;
using namespace std;

// %%
hat

// %%
//в данных уроках осутствует функция main()
//в каждом блоке этого блокнота она встроена автоматически, то есть:

// %%
//Можно сделать вот так:
#include <iostream>

using namespace std;

// %%
cout << "Hello, C++" << endl;
// Out:
// Hello, C++

// %%
// Хочу отметить, что слово 'endl' переопределено по значению переноса каретки на следующую строку 
// в первом блоке кода. Ошибка Cling - не корректная работа с std::endl

// %%
// Не рекомендуется разбирать примеры именно под jupyter notebook с ядром cling'a 
// Используйте IDE, или на начальных этапах можно потренироваться со сборкой в терминале
// Из IDE: Code::Blocks / Clion / Eclipse

// %%
// Подключаемый файл image.cpp - модуль для вставки картинок
// Значение 'hat' также определено в том же файле

// %%
// не запускайте эту строку несколько раз!
im::image pic1("images/compiling.png");

// %%
// процесс создания приложения на С++ выглядит так:
pic1

// %%
// Для компиляции в терминале используем:
// g++ -Wall -o prog prog.cpp
// Для запуска:
// ./prog
// Для прохода промежуточных точек:
// Препроцессинг
// g++ -E file.cpp -o file_preprocessed.cpp
// Компиляция
// g++ -c file1.cpp // создаст file1.o 
// это для каждого .cpp
// линковка:
// g++ file1.o file2.o ... filen.o program_name

// %%
// для просмотра ассемблер - кода:
// g++ -S file.cpp

// %%
// также разную информации можно просматривать путём objdump:
// objdump -d file.o
// objdump -x file.o // дополнительные таблицы в объектных файлах

// %%
// Конец первого урока
